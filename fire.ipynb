# %%
#clone YOLOv5 and 
#!git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images
# Out:
# /home/nikhil/self_Project/yolov5
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
os.environ["DATASET_DIRECTORY"] = "../fire_datasets"

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="KnO1HFUawybkKzxGovmP")
project = rf.workspace().project("drowsy_detection")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to ../fire_datasets/drowsy_detection-1 in yolov5pytorch:: 100%|██████████| 178/178 [00:00<00:00, 6091.75it/s]

# %%
#!python train.py --img 416 --batch 16 --epochs 150 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache

# %%
# !python detect.py --weights //home/nikhil/Downloads/fire.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['//home/nikhil/Downloads/fire.pt'], source=/home/nikhil/self_Project/fire_datasets/drowsy_detection-1/test/images, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/4 /home/nikhil/self_Project/fire_datasets/drowsy_detection-1/test/images/sleepdec10_png.rf.64d4c3d499f7fae44b1975ebefef7ec0.jpg: 416x416 Done. (0.267s)
# image 2/4 /home/nikhil/self_Project/fire_datasets/drowsy_detection-1/test/images/sleepdec23_png.rf.2020dd2f8c666fe53d86c226bf6b1677.jpg: 416x416 3 smokes, Done. (0.097s)
# ...

# %%
# !python detect.py --weights //home/nikhil/Downloads/fire.pt --img 416 --conf 0.1 --source fire.mp4
# Out:
# detect: weights=['//home/nikhil/Downloads/fire.pt'], source=fire.mp4, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2956) /home/nikhil/self_Project/yolov5/fire.mp4: 256x416 Done. (0.080s)
# video 1/1 (2/2956) /home/nikhil/self_Project/yolov5/fire.mp4: 256x416 Done. (0.051s)
# video 1/1 (3/2956) /home/nikhil/self_Project/yolov5/fire.mp4: 256x416 Done. (0.058s)
# video 1/1 (4/2956) /home/nikhil/self_Project/yolov5/fire.mp4: 256x416 Done. (0.054s)
# ...
